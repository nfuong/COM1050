# %% [markdown]
# W3A2

# %%
a = 5
b = 10
print("Trước hoán đổi: a =", a, ", b =", b)
a = a ^ b
b = a ^ b
a = a ^ b
print("Sau hoán đổi: a =", a, ", b =", b)

# %% [markdown]
# W3A3

# %%
n = int(input())
if n > 0 and (n & (n - 1)) == 0:
    print(n, "là lũy thừa của 2")
else:
    print(n, "không phải lũy thừa của 2")

# %% [markdown]
# W3A4

# %%
m = int(input("m = "))
n = int(input("n = "))
kq = m//n
print("Kết quả làm tròn xuống là:", kq)

# %% [markdown]
# W3A5

# %%
m = int(input("m = "))
n = int(input("n = "))
kq = (m+n-1)//n
print("Kết quả làm tròn lên là:", kq)
# Out:
# m = 6
# n = 5
# Kết quả làm tròn lên là: 2

# %% [markdown]
# W3A6

# %%
n = int(input())
if n >= 0:
    if n % 2 == 0:
        print(n, "là số chẵn")
    else:
        print(n, "là số lẻ")
else:
    print("Vui lòng nhập số nguyên dương")

# %% [markdown]
# W3A7

# %%
a = int(input())
b = int(input())
if a < 0 and b < 0:
    print("Yes")
else:
    print("No")

# %% [markdown]
# W3A8

# %%
a = input("Chuỗi a: ")
b = input("Chuỗi b: ")

if len(a) > len(b):
    print("True")
else:
    print("False")
# Out:
# Chuỗi a: bdashbdyuas
# Chuỗi b: svghsvcvas
# True

# %% [markdown]
# W3A9

# %%
a = int(input())
b = int(input())
c = int(input())

if a + b > c and a + c > b and b + c > a:
    print("Yes")
else:
    print("No")

# %% [markdown]
# W3A10

# %%
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))
d = int(input("d = "))

max_num = max(a, b, c, d)
print("Số lớn nhất là:", max_num)
# Out:
# a = 4
# b = 56
# c = 4
# d = 7
# Số lớn nhất là: 56

# %% [markdown]
# W3A11

# %%
a = int(input("a: "))
b = int(input("b: "))
c = int(input("c: "))

if a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print("Tam giác đều")
    elif a == b or a == c or b == c:
        print("Tam giác cân")
    else:
        print("Tam giác thường")
else:
    print("Không phải tam giác")
# Out:
# a: 5
# b: 6
# c: 7
# Tam giác thường

# %% [markdown]
# W3A12

# %%
n = int(input("Năm: "))

if (n % 4 == 0 and n % 100 != 0) or (n % 400 == 0):
    print("Yes")
else:
    print("No")

# %% [markdown]
# W3A14

# %%
a = float(input("a = "))
b = float(input("b = "))

if a == 0:
    if b == 0:
        print("Vô số nghiệm")
    else:
        print("Vô nghiệm")
else:
    print(f"Nghiệm x = {-b/a:.2f}")
# Out:
# a = 5
# b = 4
# Nghiệm x = -0.80

# %% [markdown]
# W3A15

# %%
diem = float(input("Điểm trung bình: "))

if diem >= 8.0:
    print("Giỏi")
elif diem >= 6.5:
    print("Khá")
elif diem >= 5.0:
    print("Trung bình")
else:
    print("Yếu")
# Out:
# Điểm trung bình: 7
# Khá

# %% [markdown]
# W3A16

# %%
import math
x = float(input("Nhập X: "))
print(f'Làm tròn lên: {math.ceil(x)}')
print(f'Làm tròn xuống :{math.floor(x)}')
print(f'Làm tròn {round(x)}')
# Out:
# 6.4
# 7 6 6

# %% [markdown]
# W3A17

# %%
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))
d = int(input("d = "))

an = False

if a != 0 and b % a == 0:
    r = b // a
    if b * r == c and c * r == d:
        an = True

if an:
    print("4 số tạo thành cấp số nhân với công bội", r)
else:
    print("4 số không tạo thành cấp số nhân")
# Out:
# a = 5
# b = 6
# c = 7
# d = 8
# 4 số không tạo thành cấp số nhân
